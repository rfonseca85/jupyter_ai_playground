# %% [markdown]
# # Install insightface

# %%
# !pip install onnxruntime
# !pip install insightface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: onnxruntime in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (1.16.1)
# Requirement already satisfied: coloredlogs in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from onnxruntime) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in /Library/Python/3.9/site-packages (from onnxruntime) (1.26.0)
# Requirement already satisfied: packaging in /Library/Python/3.9/site-packages (from onnxruntime) (23.2)
# Requirement already satisfied: protobuf in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from onnxruntime) (4.25.0)
# Requirement already satisfied: sympy in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from onnxruntime) (1.12)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from sympy->onnxruntime) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: insightface in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (0.7.3)
# Requirement already satisfied: numpy in /Library/Python/3.9/site-packages (from insightface) (1.26.0)
# Requirement already satisfied: onnx in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (1.15.0)
# Requirement already satisfied: tqdm in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (4.66.1)
# Requirement already satisfied: requests in /Library/Python/3.9/site-packages (from insightface) (2.31.0)
# Requirement already satisfied: matplotlib in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (3.8.1)
# Requirement already satisfied: Pillow in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (10.0.1)
# Requirement already satisfied: scipy in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (1.11.3)
# Requirement already satisfied: scikit-learn in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (1.3.2)
# Requirement already satisfied: scikit-image in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (0.22.0)
# Requirement already satisfied: easydict in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (1.11)
# Requirement already satisfied: cython in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (3.0.5)
# Requirement already satisfied: albumentations in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (1.3.1)
# Requirement already satisfied: prettytable in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from insightface) (3.9.0)
# Requirement already satisfied: PyYAML in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from albumentations->insightface) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from albumentations->insightface) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from albumentations->insightface) (4.8.1.78)
# Requirement already satisfied: networkx>=2.8 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from scikit-image->insightface) (3.2.1)
# Requirement already satisfied: imageio>=2.27 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from scikit-image->insightface) (2.31.6)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from scikit-image->insightface) (2023.9.26)
# Requirement already satisfied: packaging>=21 in /Library/Python/3.9/site-packages (from scikit-image->insightface) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from scikit-image->insightface) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from matplotlib->insightface) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from matplotlib->insightface) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from matplotlib->insightface) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from matplotlib->insightface) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from matplotlib->insightface) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from matplotlib->insightface) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from matplotlib->insightface) (6.1.0)
# Requirement already satisfied: protobuf>=3.20.2 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from onnx->insightface) (4.25.0)
# Requirement already satisfied: wcwidth in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from prettytable->insightface) (0.2.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Python/3.9/site-packages (from requests->insightface) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Python/3.9/site-packages (from requests->insightface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from requests->insightface) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Python/3.9/site-packages (from requests->insightface) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from scikit-learn->insightface) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from scikit-learn->insightface) (3.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->insightface) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->insightface) (1.15.0)
# Requirement already satisfied: typing-extensions in /Library/Python/3.9/site-packages (from qudida>=0.0.4->albumentations->insightface) (4.8.0)

# %%
import numpy as np
import os
import glob
import cv2
import matplotlib.pyplot as plt
import insightface

from insightface.app import FaceAnalysis
from insightface.data import get_image as ins_get_image

# %% [markdown]
# # Step 1 Detecting Faces

# %%
app = FaceAnalysis(name='buffalo_l')
app.prepare(ctx_id=0, det_size=(640,640))
# Out:
# /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:69: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/rafael.fonseca/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/rafael.fonseca/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/rafael.fonseca/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/rafael.fonseca/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/rafael.fonseca/.insightface/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %%
img = cv2.imread('IMG_0620.jpg')
plt.imshow(img[:,:,::-1])
plt.show()

# %%
faces = app.get(img)
# Out:
# /Users/rafael.fonseca/Library/Python/3.9/lib/python/site-packages/insightface/utils/transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4

# %%
faces[0].keys()
# Out:
# dict_keys(['bbox', 'kps', 'det_score', 'landmark_3d_68', 'pose', 'landmark_2d_106', 'gender', 'age', 'embedding'])

# %% [markdown]
# # Crop and plot Faces

# %%
img = cv2.imread('IMG_0620.jpg')
fig, axs = plt.subplots(1, 4, figsize=(12,5))

for i, face in enumerate(faces):
    bbox = face['bbox']
    bbox = [int(b) for b in bbox]
    axs[i].imshow(img[bbox[1]:bbox[3],bbox[0]:bbox[2],::-1])
    axs[i].axis('off')

# %% [markdown]
# # Get Gabi's Face

# %%
gabi_face = app.get(img)[0]
bbox = gabi_face['bbox']
bbox = [int(b) for b in bbox]
plt.imshow(img[bbox[1]:bbox[3],bbox[0]:bbox[2],::-1])
plt.show()

# %% [markdown]
# # Get Jolies Face

# %%
jolie_image = cv2.imread('jolie.jpg')
plt.imshow(jolie_image[:,:,::-1])
plt.show()

# %% [markdown]
# # Crop Jolie Face

# %%
jolie_face = app.get(jolie_image)[0]
bbox = jolie_face['bbox']
bbox = [int(b) for b in bbox]
plt.imshow(jolie_image[bbox[1]:bbox[3],bbox[0]:bbox[2],::-1])
plt.show()

# %% [markdown]
# # Swapping Faces

# %%
swapper = insightface.model_zoo.get_model('inswapper_128.onnx', download=False, download_zip=False)
res = img.copy()
res = swapper.get(res, faces[0], jolie_face, paste_back=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 swapper = insightface.model_zoo.get_model('inswapper_128.onnx', download=False, download_zip=False)
#       2 res = img.copy()
#       3 res = swapper.get(res, faces[0], jolie_face, paste_back=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/insightface/model_zoo/model_zoo.py:91, in get_model(name, **kwargs)
#      89 if not osp.exists(model_file) and allow_download:
#      90     model_file = download_onnx('models', model_file, root=root, download_zip=download_zip)
# ---> 91 assert osp.exists(model_file), 'model_file %s should exist'%model_file
#      92 assert osp.isfile(model_file), 'model_file %s should be a file'%model_file
#      93 router = ModelRouter(model_file)
#
# AssertionError: model_file inswapper_128.onnx should exist
